# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load hisat2/2.2.0

hisat2-build GCF_002042975.1_ofav_dov_v1_genomic.fna GCF_002042975.1_ofav_dov_v1_genomic_index --threads 15

# %%
mv "old_filename" "$(echo "old_filename" | sed 's/S.*_/_/')"

# %%
for f in $(ls *.fq); do mv ${f} "$(echo ${f} | sed 's/_S.*_/_/')"; done

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load hisat2/2.2.0

for f in $(ls *.fq | sed 's/_[12].fq//g'| sort -u); do hisat2 -q -x /project/pi_sarah_gignouxwolfsohn_uml_edu/Reference_genomes/Ofav_genome/GCF_002042975.1_ofav_dov_v1_genomic_index -1 ${f}_1.fq -2 ${f}_2.fq -S ../mapped/${f}mapofav.bam --un ../unmapped/${f}unmapofav.bam ; done

# %% [markdown]
# index the reference genome for samtools

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load samtools/1.9

samtools faidx GCF_002042975.1_ofav_dov_v1_genomic.fna


Submitted batch job 16130712

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load samtools/1.9

for f in $(ls *.bam| sed 's/.bam//g'); do samtools sort ${f}.bam -l 0 -o ../sorted_bam/${f}_sorted.bam ; done



Submitted batch job 16130717

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load angsd/0.935

angsd -b resistant.filelist -minMapQ 30 -minQ 20 -anc /project/pi_sarah_gignouxwolfsohn_uml_edu/Reference_genomes/Ofav_genome/GCF_002042975.1_ofav_dov_v1_genomic.fna -out ../saf/Resistant -dosaf 1 -gl 1


OFAV: Submitted batch job 16132378

PSTR: Submitted batch job  16132401

# %%
Resistant filelist ofav/oann:
Some issues where two of what i thought would be there arent?

/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T1_157_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/52022_BEL_CBC_T1_35_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_97_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/52022_BEL_CBC_T2_59_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_93_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_91_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/52022_BEL_CBC_T2_71_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_87_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/52022_BEL_CBC_T3_65_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T3_127_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T3_149_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T3_161_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T4_2_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T4_16_OFAVmapofav_sorted.bam

# %%
REsistant filelist pstr:
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_29_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T3_35_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_32_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T3_40_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T3_38_PSTRmapofav_sorted.bam

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load angsd/0.935

angsd -b susceptible.filelist -minMapQ 30 -minQ 20 -anc /project/pi_sarah_gignouxwolfsohn_uml_edu/Reference_genomes/Ofav_genome/GCF_002042975.1_ofav_dov_v1_genomic.fna -out ../saf/Susceptible -dosaf 1 -gl 1



OFAV: 
PSTR: 16132401

# %%
Susceptible filelist ofav/oann
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T1_136_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T1_120_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/52022_BEL_CBC_T1_41_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_119_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_118_OANNmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_101_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/52022_BEL_CBC_T2_72_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T2_102_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T4_9_OFAVmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/OFAV/sorted_bam/122022_BEL_CBC_T4_10_OFAVmapofav_sorted.bam

# %%
Susceptible filelist of pstr:
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_25_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_27_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_26_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_31_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_28_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T1_30_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_33_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T2_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T3_37_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T3_36_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T3_34_PSTRmapofav_sorted.bam
/project/pi_sarah_gignouxwolfsohn_uml_edu/SCTLD_metagenomes/PSTR/sorted_bam/102019_BEL_CBC_T3_39_PSTRmapofav_sorted.bam

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load angsd/0.935

realSFS Resistant.saf.idx Susceptible.saf.idx > ../sfs/Resistant.Susceptible.ml

PSTR: Submitted batch job 16132445
OFAV: Submitted batch job 16132447 OOM killed, trying again with 100000 mem

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load angsd/0.935
realSFS fst index ../saf/Resistant.saf.idx ../saf/Susceptible.saf.idx -sfs Resistant.Susceptible.ml -fstout ../fst/Resistant.Susceptible

PSTR: Submitted batch job 16132554
OFAV: Submitted batch job 16150278

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load angsd/0.935

realSFS fst print Resistant.Susceptible.fst.idx

realSFS fst stats2 Resistant.Susceptible.fst.idx -win 50000 -step 10000 >Resistant.Susceptible.slidingwindow.PSTR

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load angsd/0.935

realSFS fst print Resistant.Susceptible.fst.idx

realSFS fst stats2 Resistant.Susceptible.fst.idx -win 50000 -step 10000 >Resistant.Susceptible.slidingwindow.OFAV


Submitted batch job 16150287

# %%
Mapping to symbiont genomes. symbiont genomes have already been indexed. created conda environment for fastq_screen.

# %%
#!/bin/bash
#SBATCH --mail-type=ALL
#SBATCH -c 4  # Number of Cores per Task
#SBATCH -t 10-0:00
#SBATCH --mem=60000 # Requested Memory
#SBATCH -p cpu-preempt  # Partition
#SBATCH -c 64  # Number of CPUs
#SBATCH -o slurm-%j.out  # %j = job ID

module load miniconda/22.11.1-1

conda activate genomes


for f in $(ls *.fq| sed 's/_[12].fq//g'); 
do fastq_screen --threads 15 --subset 0 --tag --aligner Bowtie2 "$f"_1.fq "$f"_2.fq; 
done

Submitted batch job 16130938
