# %%
require(tidyr)
require(dplyr)
# Out:
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
colony=read.csv("~/Documents/SCTLD/SCTLD_samples/Sample_Data/CBC_ColonyData.csv")

# %%
sample=read.csv("~/Documents/SCTLD/SCTLD_samples/Sample_Data/CBC_samples.csv")

# %%
colony_immune=colony[colony$immune_y.n=="y",]
colony_immune=as.vector(paste0(colony_immune$TransectNum,"_", colony_immune$NewTagNum))

# %%
sample$colony=paste0(sample$TransectNum, "_", sample$NewTagNum)

# %%
sample_DNA=sample[sample$Sample_type=="Core_EtOH"|sample$Sample_type=="Core_RNAlater",]

# %%
(sample_DNA)
# Out:
#      Month_year Country Location CollectionDate Transect TransectNum OldTagNum
# 2     92023     BEL     CBC      9/25/23        CBC30N   1
# 3     92023     BEL     CBC      9/25/23        CBC30N   1
# 4     92023     BEL     CBC      9/25/23        CBC30N   1
# 5     92023     BEL     CBC      9/25/23        CBC30N   1
# 6     92023     BEL     CBC      9/25/23        CBC30N   1
# 7     92023     BEL     CBC      9/25/23        CBC30N   1
# 8     92023     BEL     CBC      9/25/23        CBC30N   1
# 9     92023     BEL     CBC      9/27/23        CBC30N   1
# 10    92023     BEL     CBC      9/27/23        CBC30N   1
# 11    92023     BEL     CBC      9/27/23        CBC30N   1
# 12    92023     BEL     CBC      9/27/23        CBC30N   1
# 13    92023     BEL     CBC      9/27/23        CBC30N   1
# 14    92023     BEL     CBC      9/27/23        CBC30N   1
# 15    92023     BEL     CBC      9/27/23        CBC30N   1
# 17    92023     BEL     CBC      9/27/23        CBC30N   1
# 18    92023     BEL     CBC      9/27/23        CBC30N   1
# 21    92023     BEL     CBC      9/27/23        CBC30N   1
# 22    92023     BEL     CBC      9/27/23        CBC30N   1
# 23    92023     BEL     CBC      9/27/23        CBC30N   1
# 24    92023     BEL     CBC      9/27/23        CBC30N   1
# 25    92023     BEL     CBC      9/27/23        CBC30N   1
# 26    92023     BEL     CBC      9/27/23        CBC30N   1
# 34   122022     BEL     CBC      12/4/22        CBC30N   1
# 40   122022     BEL     CBC      12/2/22        CBC30N   1
# 60    92023     BEL     CBC      9/26/23        SR30N    2
# 61    92023     BEL     CBC      9/26/23        SR30N    2
# 62    92023     BEL     CBC      9/26/23        SR30N    2
# 63    92023     BEL     CBC      9/26/23        SR30N    2
# 64    92023     BEL     CBC      9/26/23        SR30N    2
# 65    92023     BEL     CBC      9/26/23        SR30N    2
# ⋮    ⋮          ⋮       ⋮        ⋮              ⋮        ⋮           ⋮
# 2118  82024     BEL     CBC      8/22/24        CURLEW   4
# 2121  82024     BEL     CBC      8/22/24        CURLEW   4
# 2124  82024     BEL     CBC      8/22/24        CURLEW   4
# 2127  82024     BEL     CBC      8/22/24        CURLEW   4
# 2130  82024     BEL     CBC      8/22/24        CURLEW   4
# 2133  82024     BEL     CBC      8/22/24        CURLEW   4
# 2136  82024     BEL     CBC      8/23/24        SR30N    2
# 2139  82024     BEL     CBC      8/23/24        SR30N    2
# 2142  82024     BEL     CBC      8/23/24        SR30N    2
# 2145  82024     BEL     CBC      8/23/24        SR30N    2
# 2148  82024     BEL     CBC      8/23/24        SR30N    2
# 2151  82024     BEL     CBC      8/23/24        SR30N    2
# 2154  82024     BEL     CBC      8/23/24        SR30N    2
# 2157  82024     BEL     CBC      8/23/24        SR30N    2
# 2160  82024     BEL     CBC      8/23/24        SR30N    2
# 2163  82024     BEL     CBC      8/23/24        SR30N    2
# 2166  82024     BEL     CBC      8/23/24        SR30N    2
# 2169  82024     BEL     CBC      8/24/24        LAGOON   3
# 2172  82024     BEL     CBC      8/24/24        LAGOON   3
# 2175  82024     BEL     CBC      8/24/24        LAGOON   3
# 2178  82024     BEL     CBC      8/24/24        LAGOON   3
# 2181  82024     BEL     CBC      8/24/24        LAGOON   3
# 2183  82024     BEL     CBC      8/24/24        LAGOON   3
# 2186  82024     BEL     CBC      8/24/24        LAGOON   3
# 2189  82024     BEL     CBC      8/24/24        LAGOON   3
# 2192  82024     BEL     CBC      8/24/24        LAGOON   3
# 2195  82024     BEL     CBC      8/24/24        LAGOON   3
# 2198  82024     BEL     CBC      8/24/24        LAGOON   3
# 2201  82024     BEL     CBC      8/24/24        LAGOON   3
# 2204 122022     BEL     CBC                     LAGOON   3
#      NewTagNum Species Time_sampled ⋯ Sample_type   SampleNum Health_status
# 2    2         PAST                 ⋯ Core_RNAlater 171       Healthy
# 3    21        PAST                 ⋯ Core_RNAlater 172       Healthy
# 4    3         SSID                 ⋯ Core_RNAlater 173       Healthy
# 5    24        MCAV                 ⋯ Core_RNAlater 174       Healthy
# 6    13        PAST                 ⋯ Core_RNAlater 175       Healthy
# 7    20        PAST                 ⋯ Core_RNAlater 176       Healthy
# 8    12        PSTR                 ⋯ Core_RNAlater 177       Healthy
# 9    22        OANN                 ⋯ Core_RNAlater 190       Diseased_Tissue
# 10   7         MCAV                 ⋯ Core_RNAlater 181       Healthy
# 11   AS        PAST                 ⋯ Core_RNAlater 182       Healthy
# 12   27        DLAB                 ⋯ Core_RNAlater 183       Healthy
# 13   35        DLAB                 ⋯ Core_RNAlater 184       Healthy
# 14   1         SSID                 ⋯ Core_RNAlater 185       Diseased_Margin
# 15   22        OANN                 ⋯ Core_RNAlater 191       Diseased_Margin
# 17   5         SSID                 ⋯ Core_RNAlater 188       Diseased_Tissue
# 18   5         SSID                 ⋯ Core_RNAlater 189       Diseased_Margin
# 21   9         SSID                 ⋯ Core_RNAlater 192       Diseased_Margin
# 22   11        SSID                 ⋯ Core_RNAlater 193       Diseased_Margin
# 23   16        SSID                 ⋯ Core_RNAlater 194       Diseased_Tissue
# 24   16        SSID                 ⋯ Core_RNAlater 195       Diseased_Margin
# 25   17        SSID                 ⋯ Core_RNAlater 196       Diseased_Tissue
# 26   17        SSID                 ⋯ Core_RNAlater 197       Diseased_Margin
# 34   22        OANN                 ⋯ Core_EtOH     120       Diseased_Margin
# 40   22        OANN                 ⋯ Core_EtOH     136       Diseased_Tissue
# 60   77        OANN                 ⋯ Core_RNAlater 90        Healthy
# 61   79        OFAV                 ⋯ Core_RNAlater 171       Healthy
# 62   76        OFAV                 ⋯ Core_RNAlater 172       Healthy
# 63   73        SSID                 ⋯ Core_RNAlater 173       Healthy
# 64   72        SSID                 ⋯ Core_RNAlater 174       Healthy
# 65   68        PAST                 ⋯ Core_RNAlater 175       Healthy
# ⋮    ⋮         ⋮       ⋮            ⋱ ⋮             ⋮         ⋮
# 2118 28        MCAV    15:21        ⋯ Core_RNAlater 1605      healthy
# 2121 98        PSTR    15:25        ⋯ Core_RNAlater 1606      healthy
# 2124 79        PSTR    15:32        ⋯ Core_RNAlater 1607      healthy
# 2127 76        MCAV    15:37        ⋯ Core_RNAlater 1608      healthy
# 2130 78        OFAV    15:41        ⋯ Core_RNAlater 1609      healthy
# 2133 30        MCAV    15:45        ⋯ Core_RNAlater 1610      healthy
# 2136 76        OFAV    10:51        ⋯ Core_RNAlater 1507      healthy
# 2139 73        SSID    10:59        ⋯ Core_RNAlater 1508      healthy
# 2142 72        SSID    11:04        ⋯ Core_RNAlater 1509      healthy
# 2145 68        PAST    11:10        ⋯ Core_RNAlater 1510      healthy
# 2148 99        SSID    11:17        ⋯ Core_RNAlater 1511      healthy
# 2151 63        PAST    11:23        ⋯ Core_RNAlater 1512      healthy
# 2154 57        PAST    11:27        ⋯ Core_RNAlater 1513      healthy
# 2157 55        MCAV    11:33        ⋯ Core_RNAlater 1514      healthy
# 2160 60        MCAV    11:37        ⋯ Core_RNAlater 1515      healthy
# 2163 79        OFAV    11:42        ⋯ Core_RNAlater 1516      healthy
# 2166 69        MCAV    11:47        ⋯ Core_RNAlater 1517      healthy
# 2169 2         MCAV    10:05        ⋯ Core_RNAlater 1553      healthy
# 2172 38        OANN    10:11        ⋯ Core_RNAlater 1554      healthy
# 2175 5         SSID    10:17        ⋯ Core_RNAlater 1555      healthy
# 2178 66        OFAV    10:22        ⋯ Core_RNAlater 1556      healthy
# 2181 10        PAST    10:28        ⋯ Core_RNAlater 1557      healthy
# 2183 14        MCAV    10:32        ⋯ Core_RNAlater 1558      healthy
# 2186 20        PSTR    10:37        ⋯ Core_RNAlater 1559      healthy
# 2189 70        PSTR    10:43        ⋯ Core_RNAlater 1560      healthy
# 2192 21        MCAV    10:48        ⋯ Core_RNAlater 1561      healthy
# 2195 39        OFAV    10:52        ⋯ Core_RNAlater 1562      healthy
# 2198 33        SSID    10:56        ⋯ Core_RNAlater 1563      healthy
# 2201 34        PAST    11:02        ⋯ Core_RNAlater 1564      healthy
# 2204 AS        OANN                 ⋯ Core_EtOH     29        unknown
#      Sampling_notes
# 2    CLP 90%
# 3    No CL
# 4    CLP 80%; DC 20%
# 5    CLP 10%
# 6    No CL
# 7    No CL
# 8    No CL
# 9
# 10   Had previous TL
# 11   next to past 19, actual 19 CLB
# 12   No CL
# 13   CLP 95%
# 14   only margin sample available
# 15
# 17
# 18
# 21
# 22
# 23   CLB 90%
# 24   CLB 90%
# 25   CLB 50%
# 26   CLB 50%
# 34
# 40
# 60   CLB 70%; CLP 20%; sampled bleached tissue
# 61   CLB 20%
# 62   No CL
# 63   CLB 50%
# 64   CLP 90%
# 65   No CL
# ⋮    ⋮
# 2118
# 2121 10% CLP
# 2124
# 2127
# 2130
# 2133 5% CLB
# 2136
# 2139 80% CLP; blue
# 2142 80% CLP; blue
# 2145 some damselfish predation?
# 2148 40% CLP; slightly blue
# 2151
# 2154
# 2157
# 2160
# 2163
# 2166 old mortality
# 2169
# 2172
# 2175 60% CLP, slightly blue
# 2178
# 2181 very small samples, colony not big enough for immune
# 2183
# 2186
# 2189
# 2192
# 2195 lots of damselfish predation, sampled on opposite side of it
# 2198 discoloration- some black & purple spots
# 2201
# 2204 labelled as 't3 (lagoon)-29' & 'new oann 29' but t3 29 oann doesn’t exist and there is no record of #29 sample. Kept at room temp until 10/24
#      Tubelabel_species      Sample_physical_location
# 2    92023BELCBCT1171_PAST  UML_NARWHAL_R1_B10
# 3    92023BELCBCT1172_PAST  UML_NARWHAL_R1_B10
# 4    92023BELCBCT1173_SSID  UML_NARWHAL_R1_B10
# 5    92023BELCBCT1174_MCAV  UML_NARWHAL_R1_B10
# 6    92023BELCBCT1175_PAST  UML_NARWHAL_R1_B10
# 7    92023BELCBCT1176_PAST  UML_NARWHAL_R1_B10
# 8    92023BELCBCT1177_PSTR  UML_NARWHAL_R1_B10
# 9    92023BELCBCT1190_OANN  UML_NARWHAL_R1_B10
# 10   92023BELCBCT1181_MCAV  UML_NARWHAL_R1_B10
# 11   92023BELCBCT1182_PAST  UML_NARWHAL_R1_B10
# 12   92023BELCBCT1183_DLAB  UML_NARWHAL_R1_B10
# 13   92023BELCBCT1184_DLAB  UML_NARWHAL_R1_B10
# 14   92023BELCBCT1185_SSID  UML_NARWHAL_R1_B10
# 15   92023BELCBCT1191_OANN  UML_NARWHAL_R1_B10
# 17   92023BELCBCT1188_SSID  UML_NARWHAL_R1_B10
# 18   92023BELCBCT1189_SSID  UML_NARWHAL_R1_B10
# 21   92023BELCBCT1192_SSID  UML_NARWHAL_R1_B10
# 22   92023BELCBCT1193_SSID  UML_NARWHAL_R1_B10
# 23   92023BELCBCT1194_SSID  UML_NARWHAL_R1_B10
# 24   92023BELCBCT1195_SSID  UML_NARWHAL_R1_B10
# 25   92023BELCBCT1196_SSID  UML_NARWHAL_R1_B10
# 26   92023BELCBCT1197_SSID  UML_NARWHAL_R1_B10
# 34   122022BELCBCT1120_OANN Depleted_UML_NARWHAL_R1_B4
# 40   122022BELCBCT1136_OANN Depleted_UML_NARWHAL_R1_B4
# 60   92023BELCBCT290_OANN   UML_NARWHAL_R1_B10
# 61   92023BELCBCT2171_OFAV  UML_NARWHAL_R1_B10
# 62   92023BELCBCT2172_OFAV  UML_NARWHAL_R1_B10
# 63   92023BELCBCT2173_SSID  UML_NARWHAL_R1_B10
# 64   92023BELCBCT2174_SSID  UML_NARWHAL_R1_B10
# 65   92023BELCBCT2175_PAST  UML_NARWHAL_R1_B10
# ⋮    ⋮                      ⋮
# 2118 82024BELCBCT41605_MCAV
# 2121 82024BELCBCT41606_PSTR
# 2124 82024BELCBCT41607_PSTR
# 2127 82024BELCBCT41608_MCAV
# 2130 82024BELCBCT41609_OFAV
# 2133 82024BELCBCT41610_MCAV
# 2136 82024BELCBCT21507_OFAV
# 2139 82024BELCBCT21508_SSID
# 2142 82024BELCBCT21509_SSID
# 2145 82024BELCBCT21510_PAST
# 2148 82024BELCBCT21511_SSID
# 2151 82024BELCBCT21512_PAST
# 2154 82024BELCBCT21513_PAST
# 2157 82024BELCBCT21514_MCAV
# 2160 82024BELCBCT21515_MCAV
# 2163 82024BELCBCT21516_OFAV
# 2166 82024BELCBCT21517_MCAV
# 2169 82024BELCBCT31553_MCAV
# 2172 82024BELCBCT31554_OANN
# 2175 82024BELCBCT31555_SSID
# 2178 82024BELCBCT31556_OFAV
# 2181 82024BELCBCT31557_PAST
# 2183 82024BELCBCT31558_MCAV
# 2186 82024BELCBCT31559_PSTR
# 2189 82024BELCBCT31560_PSTR
# 2192 82024BELCBCT31561_MCAV
# 2195 82024BELCBCT31562_OFAV
# 2198 82024BELCBCT31563_SSID
# 2201 82024BELCBCT31564_PAST
# 2204 122022BELCBCT329_OANN  UML_NARWHAL_R1_B5
#      Extraction_physical_location Date_sequenced Notes colony
# 2                                                      1_2
# 3                                                      1_21
# 4                                                      1_3
# 5                                                      1_24
# 6                                                      1_13
# 7                                                      1_20
# 8                                                      1_12
# 9    UML_NARWHAL_R2_B11                                1_22
# 10                                                     1_7
# 11                                                     1_AS
# 12                                                     1_27
# 13                                                     1_35
# 14                                                     1_1
# 15                                                     1_22
# 17   UML_NARWHAL_R2_B11                                1_5
# 18                                                     1_5
# 21                                                     1_9
# 22                                                     1_11
# 23   UML_NARWHAL_R2_B11                                1_16
# 24                                                     1_16
# 25   UML_NARWHAL_R2_B11                                1_17
# 26                                                     1_17
# 34   UML_NARWHAL_R2_B3                                 1_22
# 40   UML_NARWHAL_R2_B3                                 1_22
# 60                                                     2_77
# 61                                                     2_79
# 62                                                     2_76
# 63                                                     2_73
# 64                                                     2_72
# 65                                                     2_68
# ⋮    ⋮                            ⋮              ⋮     ⋮
# 2118                                                   4_28
# 2121                                                   4_98
# 2124                                                   4_79
# 2127                                                   4_76
# 2130                                                   4_78
# 2133                                                   4_30
# 2136                                                   2_76
# 2139                                                   2_73
# 2142                                                   2_72
# 2145                                                   2_68
# 2148                                                   2_99
# 2151                                                   2_63
# 2154                                                   2_57
# 2157                                                   2_55
# 2160                                                   2_60
# 2163                                                   2_79
# 2166                                                   2_69
# 2169                                                   3_2
# 2172                                                   3_38
# 2175                                                   3_5
# 2178                                                   3_66
# 2181                                                   3_10
# 2183                                                   3_14
# 2186                                                   3_20
# 2189                                                   3_70
# 2192                                                   3_21
# 2195                                                   3_39
# 2198                                                   3_33
# 2201                                                   3_34
# 2204                                                   3_AS

# %%
sample_extract=sample_DNA[sample_DNA$Extraction_physical_location=="",]
sample_extract=as.vector(sample_extract$Tubelabel_species)

# %%
sample_DNA=sample_DNA[c("Month_year", "Health_status", "colony", "Tubelabel_species")]

# %%
sample_DNA=sample_DNA[c("Month_year",  "colony", "Tubelabel_species")]

# %%
head(sample_extract)
# Out:
# [1] "92023BELCBCT1171_PAST" "92023BELCBCT1172_PAST" "92023BELCBCT1173_SSID"
# [4] "92023BELCBCT1174_MCAV" "92023BELCBCT1175_PAST" "92023BELCBCT1176_PAST"

# %%
head(sample_DNA)
# Out:
#   Month_year colony Tubelabel_species
# 2 92023      1_2    92023BELCBCT1171_PAST
# 3 92023      1_21   92023BELCBCT1172_PAST
# 4 92023      1_3    92023BELCBCT1173_SSID
# 5 92023      1_24   92023BELCBCT1174_MCAV
# 6 92023      1_13   92023BELCBCT1175_PAST
# 7 92023      1_20   92023BELCBCT1176_PAST

# %%
sample_extract=sample_DNA[sample_DNA$Tubelabel_species %in% sample_extract,]

# %%
tail(sample_extract)
# Out:
#      Month_year colony Tubelabel_species
# 2189  82024     3_70   82024BELCBCT31560_PSTR
# 2192  82024     3_21   82024BELCBCT31561_MCAV
# 2195  82024     3_39   82024BELCBCT31562_OFAV
# 2198  82024     3_33   82024BELCBCT31563_SSID
# 2201  82024     3_34   82024BELCBCT31564_PAST
# 2204 122022     3_AS   122022BELCBCT329_OANN

# %%
sample_matrix=pivot_wider(sample_DNA, names_from = Month_year, values_from = Tubelabel_species, values_fn = function(x) paste(x, collapse = " "))

# %%
sample_matrix_extract=pivot_wider(sample_extract, names_from = Month_year, values_from = Tubelabel_species, values_fn = function(x) paste(x, collapse = " "))

# %%
sample_matrix= sample_matrix[, c("colony", "62019", "102019", "52022", "122022", "92023", "112023", "122023", "22024", "42024", "62024", "82024")]

# %%
sample_matrix_extract= sample_matrix_extract[, c("colony", "62019", "102019", "52022", "122022", "92023", "112023", "122023", "22024", "42024", "62024", "82024")]

# %%
sample_matrix_immune=sample_matrix[sample_matrix$colony %in% colony_immune,]

# %%
sample_matrix_extract_immune=sample_matrix_extract[sample_matrix_extract$colony %in% colony_immune,]

# %%
write.csv(sample_matrix_immune, file="~/Documents/SCTLD/Belize/sample_table_immune_all.csv")

# %%
write.csv(sample_matrix_extract_immune, file="~/Documents/SCTLD/Belize/sample_table_immune_toextract.csv")

# %%
sample_extract
# Out:
#   Month_year Country Location CollectionDate Transect TransectNum OldTagNum
# 1 122022     BEL     CBC      12/5/22        CURLEW   4
# 2  92023     BEL     CBC      9/25/23        CBC30N   1
# 3  92023     BEL     CBC      9/25/23        CBC30N   1
# 4  92023     BEL     CBC      9/25/23        CBC30N   1
# 5  92023     BEL     CBC      9/25/23        CBC30N   1
# 6  92023     BEL     CBC      9/25/23        CBC30N   1
#   NewTagNum Species Time_sampled ⋯ Sample_type   SampleNum Health_status
# 1 77        OFAV                 ⋯ Core_frozen   18        Healthy
# 2 2         PAST                 ⋯ Core_RNAlater 171       Healthy
# 3 21        PAST                 ⋯ Core_RNAlater 172       Healthy
# 4 3         SSID                 ⋯ Core_RNAlater 173       Healthy
# 5 24        MCAV                 ⋯ Core_RNAlater 174       Healthy
# 6 13        PAST                 ⋯ Core_RNAlater 175       Healthy
#   Sampling_notes  Tubelabel_species          Sample_physical_location
# 1                 122022_BEL_CBC_T4_18_OFAV
# 2 CLP 90%         092023_BEL_CBC_T1_171_PAST UML_NARWHAL_R1_B10
# 3 No CL           092023_BEL_CBC_T1_172_PAST UML_NARWHAL_R1_B10
# 4 CLP 80%; DC 20% 092023_BEL_CBC_T1_173_SSID UML_NARWHAL_R1_B10
# 5 CLP 10%         092023_BEL_CBC_T1_174_MCAV UML_NARWHAL_R1_B10
# 6 No CL           092023_BEL_CBC_T1_175_PAST UML_NARWHAL_R1_B10
#   Extraction_physical_location Date_sequenced Notes colony
# 1                                                   4_77_OFAV
# 2                                                   1_2_PAST
# 3                                                   1_21_PAST
# 4                                                   1_3_SSID
# 5                                                   1_24_MCAV
# 6                                                   1_13_PAST

# %%
head(sample)
# Out:
#   Month_year Country Location CollectionDate Transect TransectNum OldTagNum
# 1 122022     BEL     CBC      12/5/22        CURLEW   4
# 2  92023     BEL     CBC      9/25/23        CBC30N   1
# 3  92023     BEL     CBC      9/25/23        CBC30N   1
# 4  92023     BEL     CBC      9/25/23        CBC30N   1
# 5  92023     BEL     CBC      9/25/23        CBC30N   1
# 6  92023     BEL     CBC      9/25/23        CBC30N   1
#   NewTagNum Species Time_sampled Time_processed Sample_type   SampleNum
# 1 77        OFAV                                Core_frozen   18
# 2 2         PAST                                Core_RNAlater 171
# 3 21        PAST                                Core_RNAlater 172
# 4 3         SSID                                Core_RNAlater 173
# 5 24        MCAV                                Core_RNAlater 174
# 6 13        PAST                                Core_RNAlater 175
#   Health_status Sampling_notes  Tubelabel_species
# 1 Healthy                       122022_BEL_CBC_T4_18_OFAV
# 2 Healthy       CLP 90%         092023_BEL_CBC_T1_171_PAST
# 3 Healthy       No CL           092023_BEL_CBC_T1_172_PAST
# 4 Healthy       CLP 80%; DC 20% 092023_BEL_CBC_T1_173_SSID
# 5 Healthy       CLP 10%         092023_BEL_CBC_T1_174_MCAV
# 6 Healthy       No CL           092023_BEL_CBC_T1_175_PAST
#   Sample_physical_location Extraction_physical_location Date_sequenced Notes
# 1
# 2 UML_NARWHAL_R1_B10
# 3 UML_NARWHAL_R1_B10
# 4 UML_NARWHAL_R1_B10
# 5 UML_NARWHAL_R1_B10
# 6 UML_NARWHAL_R1_B10
